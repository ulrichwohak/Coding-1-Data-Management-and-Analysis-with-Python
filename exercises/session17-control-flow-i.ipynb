# %% [markdown]
# # Session 17 Exercise: Control Flow I
#
# Practice conditionals and loops.

# %%
prices = [95, 120, 180, 210, 75, 140]

# TODO: loop over prices and print "budget", "standard", or "expensive" for each value.

# %% [markdown]
# Count how many prices are below 100, between 100 and 180, and above 180.

# %%
# TODO: use counters and if/elif/else.
