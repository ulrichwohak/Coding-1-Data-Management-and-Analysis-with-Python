# %% [markdown]
# # Session 15 Exercise: Plotnine II
#
# Practice hotel visualization choices.

# %%
import pandas as pd
from plotnine import aes, facet_wrap, geom_point, ggplot, labs, theme_minimal

from pathlib import Path


def find_repo_root():
    for base in (Path.cwd(), *Path.cwd().parents):
        if (base / "pyproject.toml").exists():
            return base
    return Path.cwd()


ROOT = find_repo_root()

DATA_DIR = ROOT / "data" / "raw"

price = pd.read_csv(DATA_DIR / "hotels_europe_price.csv")
features = pd.read_csv(DATA_DIR / "hotels_europe_features.csv")

# TODO: merge or select data needed for your plot.

# %% [markdown]
# Make one plot that compares at least two hotel groups. Use color, facets, or both. Write one sentence below the plot describing what you see.

# %%
# TODO: create the comparison plot.

# %% [markdown]
# Observation: TODO write one sentence here.
