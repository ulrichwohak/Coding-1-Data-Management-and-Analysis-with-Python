# %% [markdown]
# # Session 07 Exercise: Data I/O I
#
# Practice paths, text files, and encodings.

# %%
from pathlib import Path


def find_repo_root():
    for base in (Path.cwd(), *Path.cwd().parents):
        if (base / "pyproject.toml").exists():
            return base
    return Path.cwd()


ROOT = find_repo_root()

message_path = ROOT / "lectures" / "lecture03-data-IO" / "message.txt"
city_path = ROOT / "lectures" / "lecture03-data-IO" / "city_names.txt"

# TODO: read message.txt into a string and print its length.

# %% [markdown]
# Read `city_names.txt` into a list of cleaned city names. How many names are present?

# %%
# TODO: use read_text(...), splitlines(), and strip().

# %% [markdown]
# Create a new list with only city names longer than six characters.

# %%
# TODO: filter the city list.
