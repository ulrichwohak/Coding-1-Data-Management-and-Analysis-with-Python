# %% [markdown]
# # Session 12 Exercise: Pandas Munging II
#
# Practice missing values, duplicates, pipes, and a small cleaning case.

# %%
import pandas as pd

from pathlib import Path


def find_repo_root():
    for base in (Path.cwd(), *Path.cwd().parents):
        if (base / "pyproject.toml").exists():
            return base
    return Path.cwd()


ROOT = find_repo_root()

DATA_DIR = ROOT / "data" / "raw"

hotels_raw = pd.read_csv(DATA_DIR / "hotel_vienna_raw.csv")
hotels_raw.head()

# %% [markdown]
# Find columns with missing values and count how many missing values each has.

# %%
# TODO: use .isna().sum().

# %% [markdown]
# Build a small cleaning pipeline with `.pipe(...)` or chained operations. Keep it readable and assign the result to `hotels_clean`.

# %%
# TODO: write one or two small helper functions, then use .pipe(...).
