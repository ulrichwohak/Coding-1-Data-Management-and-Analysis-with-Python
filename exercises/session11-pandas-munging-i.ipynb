# %% [markdown]
# # Session 11 Exercise: Pandas Munging I
#
# Practice filtering, deriving variables, and cleaning.

# %%
import pandas as pd

from pathlib import Path


def find_repo_root():
    for base in (Path.cwd(), *Path.cwd().parents):
        if (base / "pyproject.toml").exists():
            return base
    return Path.cwd()


ROOT = find_repo_root()

hotels = pd.read_csv(ROOT / "lectures" / "lecture04-pandas-basics" / "hotel_vienna_restricted.csv")
hotels.head()

# %% [markdown]
# Filter to a subset of hotels using at least two conditions. Store the result in a new DataFrame.

# %%
# TODO: create a filtered DataFrame.

# %% [markdown]
# Create a derived variable that helps compare hotel prices. Examples: price bins, log price, or a high-rating indicator.

# %%
# TODO: assign a new column.
