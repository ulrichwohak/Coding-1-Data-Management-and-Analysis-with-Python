# %% [markdown]
# # Session 16 Exercise: Matplotlib
#
# Practice figures, axes, subplots, and annotation.

# %%
import matplotlib.pyplot as plt
import pandas as pd

from pathlib import Path


def find_repo_root():
    for base in (Path.cwd(), *Path.cwd().parents):
        if (base / "pyproject.toml").exists():
            return base
    return Path.cwd()


ROOT = find_repo_root()

DATA_DIR = ROOT / "data" / "raw"

sp500 = pd.read_csv(DATA_DIR / "sp500.csv")
sp500.head()

# %% [markdown]
# Create a figure with two axes. Put a line plot on the first axis and a histogram or bar chart on the second.

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# TODO: draw on axes[0] and axes[1].
# TODO: add titles and at least one annotation.

plt.tight_layout()
