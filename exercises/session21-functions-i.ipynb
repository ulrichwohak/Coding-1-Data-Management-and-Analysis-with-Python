# %% [markdown]
# # Session 21 Exercise: Functions I
#
# Practice defining and refactoring functions.

# %%
import pandas as pd

from pathlib import Path


def find_repo_root():
    for base in (Path.cwd(), *Path.cwd().parents):
        if (base / "pyproject.toml").exists():
            return base
    return Path.cwd()


ROOT = find_repo_root()

DATA_DIR = ROOT / "data" / "raw"

sp500 = pd.read_csv(DATA_DIR / "sp500.csv")
sp500.head()

# %% [markdown]
# Write a function that accepts a DataFrame and a column name, then returns a small dictionary of summary statistics.

# %%
def summarize_column(data, column):
    # TODO: return count, mean, median, min, and max.
    pass


# TODO: call summarize_column(...) on one numeric column.

# %% [markdown]
# Refactor repeated cleaning or plotting code from an earlier exercise into a function.

# %%
# TODO: define and call your helper function.
