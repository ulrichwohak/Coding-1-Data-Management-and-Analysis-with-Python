# %% [markdown]
# # Session 03 Exercise: Coding Basics I
#
# Practice variables, expressions, and primitive types. This should take about 10-15 minutes.

# %%
course_name = "Coding 1"
sessions_per_week = 2
minutes_per_session = 90
weeks = 12

# TODO: compute total classroom hours and store the result in total_hours.

# %% [markdown]
# Create three variables describing a dataset you might analyze: a string name, an integer row count, and a boolean flag for whether it contains missing values. Then print one sentence that uses all three.

# %%
# TODO: define your variables and print the sentence here.

# %% [markdown]
# Use `type()` to check at least four objects above. Which types do you expect before running the cell?

# %%
# TODO: call type(...) on your variables.
