# %% [markdown]
# # Session 05 Exercise: Basic Structures I
#
# Practice lists, tuples, and sets.

# %%
hotel_prices = [120, 95, 180, 120, 140, 210, 95]
coordinates = (48.2082, 16.3738)

# TODO: find the number of prices, the first price, and the last price.

# %% [markdown]
# Create a sorted list of unique prices. Then add one new observed price and recompute the unique values.

# %%
# TODO: use set(...) and sorted(...).

# %% [markdown]
# Write a short check that returns `True` if every price is positive.

# %%
# TODO: use a loop or a built-in function.
