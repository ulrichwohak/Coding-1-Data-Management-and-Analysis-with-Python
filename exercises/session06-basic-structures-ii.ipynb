# %% [markdown]
# # Session 06 Exercise: Basic Structures II
#
# Practice dictionaries, JSON, and modules.

# %%
import json
import sys

from pathlib import Path


def find_repo_root():
    for base in (Path.cwd(), *Path.cwd().parents):
        if (base / "pyproject.toml").exists():
            return base
    return Path.cwd()


ROOT = find_repo_root()

module_dir = ROOT / "lectures" / "lecture02-basic-structures"
if str(module_dir) not in sys.path:
    sys.path.insert(0, str(module_dir))

import sample_module

hotel = {
    "name": "Example Hotel",
    "city": "Vienna",
    "price": 120,
    "stars": 4,
}

# TODO: add a new key named "good_deal" with a boolean value.

# %% [markdown]
# Convert the dictionary to a JSON string with indentation. Then convert it back to a dictionary and inspect the result.

# %%
# TODO: use json.dumps(...) and json.loads(...).

# %% [markdown]
# Call one function or object from `sample_module`. Inspect `sample_module.py` if needed.

# %%
# TODO: try sample_module.<name>.
