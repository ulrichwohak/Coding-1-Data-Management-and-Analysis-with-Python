# %% [markdown]
# # Session 14 Exercise: Plotnine I
#
# Practice the grammar of graphics.

# %%
import pandas as pd
from plotnine import aes, geom_point, ggplot, labs, theme_minimal

from pathlib import Path


def find_repo_root():
    for base in (Path.cwd(), *Path.cwd().parents):
        if (base / "pyproject.toml").exists():
            return base
    return Path.cwd()


ROOT = find_repo_root()

DATA_DIR = ROOT / "data" / "raw"

hotel_prices = pd.read_csv(DATA_DIR / "hotels_europe_price.csv")
hotel_features = pd.read_csv(DATA_DIR / "hotels_europe_features.csv")

# TODO: inspect both tables before plotting.

# %% [markdown]
# Create a scatter plot with one price-related variable and one location or quality variable. Add labels and a minimal theme.

# %%
# TODO: build a ggplot object.
