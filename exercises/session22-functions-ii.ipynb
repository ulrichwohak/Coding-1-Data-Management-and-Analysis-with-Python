# %% [markdown]
# # Session 22 Exercise: Functions II
#
# Practice lambdas, scope, and reusable analysis helpers.

# %%
import pandas as pd

from pathlib import Path


def find_repo_root():
    for base in (Path.cwd(), *Path.cwd().parents):
        if (base / "pyproject.toml").exists():
            return base
    return Path.cwd()


ROOT = find_repo_root()

hotels = pd.read_csv(ROOT / "lectures" / "lecture04-pandas-basics" / "hotel_vienna_restricted.csv")
hotels.head()

# %% [markdown]
# Use `.assign(...)` with a lambda to create one derived column without mutating the original DataFrame.

# %%
# TODO: use hotels.assign(new_column=lambda df: ...).

# %% [markdown]
# Write a function that takes a DataFrame and returns a filtered copy. Make the threshold an argument with a default value.

# %%
def filter_hotels(data, threshold=100):
    # TODO: return a filtered copy.
    pass


# TODO: call filter_hotels(...) with two thresholds.
