# %% [markdown]
# # Session 25 Exercise: Regression II
#
# Practice OLS, predictions, residuals, and hotel-deal interpretation.

# %%
import pandas as pd
import statsmodels.formula.api as smf

from pathlib import Path


def find_repo_root():
    for base in (Path.cwd(), *Path.cwd().parents):
        if (base / "pyproject.toml").exists():
            return base
    return Path.cwd()


ROOT = find_repo_root()

DATA_DIR = ROOT / "data" / "raw"

hotels = pd.read_csv(DATA_DIR / "hotels_vienna.csv")
hotels.head()

# %% [markdown]
# Estimate a simple OLS model with hotel price as the outcome and one location or quality variable as the predictor.

# %%
# TODO: replace formula terms with columns that exist in the data.
# model = smf.ols("price ~ distance", data=hotels).fit()
# model.summary()

# %% [markdown]
# Add predictions and residuals to a copy of the data. Identify a few hotels with negative residuals and describe why they might be candidate deals.

# %%
# TODO: use model.predict(...) and actual minus predicted values.
