# %% [markdown]
# # Session 18 Exercise: Control Flow II
#
# Practice comprehensions and loop refactoring.

# %%
raw_names = [" Vienna ", "BUDAPEST", "prague", "Bratislava ", "vienna"]

# TODO: use a list comprehension to clean capitalization and whitespace.

# %% [markdown]
# Use a dictionary comprehension to count the length of each unique cleaned city name.

# %%
# TODO: create a dictionary named city_lengths.

# %% [markdown]
# Refactor one comprehension into a regular loop. Which version is easier to read here?

# %%
# TODO: write the loop version.
