# %% [markdown]
# # Session 24 Exercise: Regression I
#
# Practice binary means, binscatter thinking, and lowess setup.

# %%
import pandas as pd
from statsmodels.nonparametric.smoothers_lowess import lowess

from pathlib import Path


def find_repo_root():
    for base in (Path.cwd(), *Path.cwd().parents):
        if (base / "pyproject.toml").exists():
            return base
    return Path.cwd()


ROOT = find_repo_root()

DATA_DIR = ROOT / "data" / "raw"

hotels = pd.read_csv(DATA_DIR / "hotels_vienna.csv")
hotels.head()

# %% [markdown]
# Create a binary grouping variable from one hotel feature. Compare mean price across the two groups.

# %%
# TODO: create the group and compare means.

# %% [markdown]
# Choose a distance or location variable and a price variable. Use `lowess` to compute a smooth relationship.

# %%
# TODO: prepare x/y arrays and call lowess(...).
