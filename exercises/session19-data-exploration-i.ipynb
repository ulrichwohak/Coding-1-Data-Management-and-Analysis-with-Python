# %% [markdown]
# # Session 19 Exercise: Data Exploration I
#
# Practice descriptive statistics and distributions.

# %%
import pandas as pd

from pathlib import Path


def find_repo_root():
    for base in (Path.cwd(), *Path.cwd().parents):
        if (base / "pyproject.toml").exists():
            return base
    return Path.cwd()


ROOT = find_repo_root()

DATA_DIR = ROOT / "data" / "raw"

bpp = pd.read_csv(DATA_DIR / "billion_prices.csv", encoding="latin-1")
bpp.head()

# %% [markdown]
# Choose one numeric column. Compute count, mean, median, standard deviation, minimum, and maximum.

# %%
# TODO: summarize one numeric column.

# %% [markdown]
# Create a histogram for the same variable. Try two different bin widths or bin counts.

# %%
# TODO: create histograms using pandas or matplotlib.
