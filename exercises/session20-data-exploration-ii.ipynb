# %% [markdown]
# # Session 20 Exercise: Data Exploration II
#
# Practice association, correlation, and hypothesis-test setup.

# %%
import pandas as pd
from scipy import stats

from pathlib import Path


def find_repo_root():
    for base in (Path.cwd(), *Path.cwd().parents):
        if (base / "pyproject.toml").exists():
            return base
    return Path.cwd()


ROOT = find_repo_root()

DATA_DIR = ROOT / "data" / "raw"

bpp = pd.read_csv(DATA_DIR / "billion_prices.csv", encoding="latin-1")
bpp.head()

# %% [markdown]
# Pick two numeric columns that could plausibly be related. Compute their correlation after handling missing values.

# %%
# TODO: select two columns and call .corr(...).

# %% [markdown]
# Define two groups and compare the mean of one numeric variable across the groups. Then run a simple two-sample t-test if the setup is appropriate.

# %%
# TODO: use scipy.stats.ttest_ind on two cleaned Series.
