# %% [markdown]
# # Session 09 Exercise: Pandas Basics I
#
# Practice Series and DataFrames with the Vienna hotel data.

# %%
import pandas as pd

from pathlib import Path


def find_repo_root():
    for base in (Path.cwd(), *Path.cwd().parents):
        if (base / "pyproject.toml").exists():
            return base
    return Path.cwd()


ROOT = find_repo_root()

hotels = pd.read_csv(ROOT / "lectures" / "lecture04-pandas-basics" / "hotel_vienna_restricted.csv")
hotels.head()

# %% [markdown]
# Inspect the shape, column names, and dtypes. Identify one numeric column and one text or categorical column.

# %%
# TODO: use .shape, .columns, and .dtypes.

# %% [markdown]
# Create a `Series` from one numeric column and compute its minimum, maximum, and mean.

# %%
# TODO: choose a column and summarize it.
