# %% [markdown]
# # Session 10 Exercise: Pandas Basics II
#
# Practice indexing, selection, and metadata.

# %%
import pandas as pd

from pathlib import Path


def find_repo_root():
    for base in (Path.cwd(), *Path.cwd().parents):
        if (base / "pyproject.toml").exists():
            return base
    return Path.cwd()


ROOT = find_repo_root()

hotels = pd.read_csv(ROOT / "lectures" / "lecture04-pandas-basics" / "hotel_vienna_restricted.csv")
hotels.head()

# %% [markdown]
# Select five rows and three columns using both label-based and position-based selection.

# %%
# TODO: use .loc[...] and .iloc[...].

# %% [markdown]
# Sort the data by a numeric column and display the top ten rows. Then reset the index.

# %%
# TODO: use sort_values(...) and reset_index(...).
