# %% [markdown]
# # Session 23 Exercise: Exceptions
#
# Practice defensive coding around data workflow failures.

# %%
from pathlib import Path
import pandas as pd

from pathlib import Path


def find_repo_root():
    for base in (Path.cwd(), *Path.cwd().parents):
        if (base / "pyproject.toml").exists():
            return base
    return Path.cwd()


ROOT = find_repo_root()


def load_csv(path):
    # TODO: handle FileNotFoundError and pd.errors.EmptyDataError with clear messages.
    return pd.read_csv(path)


existing_path = ROOT / "lectures" / "lecture04-pandas-basics" / "hotel_vienna_restricted.csv"
missing_path = ROOT / "data" / "raw" / "does_not_exist.csv"

# %% [markdown]
# Call your function on both paths. Confirm that the existing file loads and the missing file fails informatively.

# %%
# TODO: call load_csv(existing_path) and load_csv(missing_path).
