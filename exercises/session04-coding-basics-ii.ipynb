# %% [markdown]
# # Session 04 Exercise: Coding Basics II
#
# Practice strings, operators, and readable code style.

# %%
city = "Vienna"
country = "Austria"
price = 127.456
rating = 8.7

# TODO: create a compact hotel label such as "Vienna, Austria: rating 8.7, price 127.46".

# %% [markdown]
# Build a simple SQL-like filter string for hotels with price below 150 and rating at least 8.5. Use variables instead of hard-coding the numbers inside the final string.

# %%
max_price = 150
min_rating = 8.5

# TODO: create filter_expression.

# %% [markdown]
# Refactor one long expression into two or three intermediate variables with clear names.

# %%
# TODO: write the refactored expression here.
