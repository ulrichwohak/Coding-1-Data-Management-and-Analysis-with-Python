# %% [markdown]
# # Session 08 Exercise: Data I/O II
#
# Practice reading, writing, and organizing small files.

# %%
from pathlib import Path


def find_repo_root():
    for base in (Path.cwd(), *Path.cwd().parents):
        if (base / "pyproject.toml").exists():
            return base
    return Path.cwd()


ROOT = find_repo_root()

work_dir = ROOT / "scratch" / "session08"
work_dir.mkdir(parents=True, exist_ok=True)

# TODO: write a short note to work_dir / "note.txt".

# %% [markdown]
# Read the file back and verify that the text matches what you wrote.

# %%
# TODO: read your note and compare strings.

# %% [markdown]
# List the files in `work_dir`. Then add one more small file and list the directory again.

# %%
# TODO: use Path.iterdir().
